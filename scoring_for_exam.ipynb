# %%
import numpy as np
import pandas as pd
import streamlit as st


N = 100
n = 20

scorelist = [1,2,3]
scorelist = np.array(scorelist)
scorelist.sum()
# scorelist = input("문항 배점 리스트(2,3,4,5,6과 같이 수와 컴마로만 입력해주세요. :")

# if scorelist!="":
#   score = list(map(float, scorelist.split(",")))
#   N = int(N)
#   n = int(n)
#   case = []
# # 배점당 2문제 이상은 있도록 설정(range(2, n-1))
#   for s in range(2,n-1):
#     for w in range(2,n-1):
#       for z in range(2,n-1):
#         for y in range(2,n-1):
#           for x in range(2,n-1):
#             if (x+y+z+w+s == n)&(score[0]*x+score[1]*y+score[2]*z+score[3]*w+score[4]*s== N)&(z>=np.floor(n/5)) : 
#               # 배점이 중간인 문항 수가 나머지보다 적지는 않게
#               print(x,y,z,w,s)
#               case.append([x,y,z,w,s])
#             else :
#               continue
#   if len(case)==0:
#     print('가능한 문항 수가 존재하지 않습니다. 문항 수나 배점 리스트를 다시 설정하세요. ')
#   else : 
#     print('{}가지 모든 경우를 출력하였습니다. '.format(len(case)))

#sample
# 3.6, 3.8, 4.0, 4.2, 4.4
# 4.1, 4.3, 4.5, 4.7, 4.9
# Out:
# 6

# %%
n = 5
variables = {}
for i in range(n):
    variables[f"x{i+1}"] = None

variables['x1']==1
# Out:
# False

# %%
for s in range(2,n-1):
  for w in range(2,n-1):
    for z in range(2,n-1):
      for y in range(2,n-1):
        for x in range(2,n-1):
          if x+y+z+w+s != n:
            continue
          elif:
            score[0]*x+score[1]*y+score[2]*z+score[3]*w+score[4]*s== N
            #)&(z>=np.floor(n/5)) : 
            # 배점이 중간인 문항 수가 나머지보다 적지는 않게
            st.write(x,y,z,w,s)
            case.append([x,y,z,w,s])
          else :
            continue

# %%
for i in range(1, 4):
	globals()['x' + str(i)] = 10
	# globals()['test{}'.format(i)] = i * 10
 
print(globals())
# 결과 : {생략, 'test1': 10, 'test2': 20, 'test3': 30}
 
# 결과 : 10 20 30
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'import numpy as np\nimport pandas as pd\nimport streamlit as st\n\n\n\n\nN = 100\nn = 20\n\nscorelist = input("문항 배점 리스트(2,3,4,5,6과 같이 수와 컴마로만 입력해주세요. :")\n########\n\n\n\nif scorelist!="":\n  score = list(map(float, scorelist.split(",")))\n  N = int(N)\n  n = int(n)\n  case = []\n# 배점당 2문제 이상은 있도록 설정(range(2, n-1))\n  for s in range(2,n-1):\n    for w in range(2,n-1):\n      for z in range(2,n-1):\n        for y in range(2,n-1):\n          for x in range(2,n-1):\n            if (x+y+z+w+s == n)&(score[0]*x+score[1]*y+score[2]*z+score[3]*w+score[4]*s== N)&(z>=np.floor(n/5)) : \n              # 배점이 중간인 문항 수가 나머지보다 적지는 않게\n              print(x,y,z,w,s)\n              case.append([x,y,z,w,s])\n            else :\n              continue\n\n  if len(case)==0:\n    print(\'가능한 문항 수가 존재하지 않습니다. 문항 수나 배점 리스트를 다시 설정하세요. \')\n  else : \n    print(\'{}가지 모든 경우를 출력하였습니다. \'.format(len(case)))\n\n\n#st.dataframe(pd.DataFrame(case), use_container_width=True)\n\n#sample\n# 3.6, 3.8, 4.0, 4.2, 4.4\n# 4.1, 4.3, 4.5, 4.7, 4.9', 'import numpy as np\nimport pandas as pd\nimport streamlit as st\n\n\nN = 100\nn = 20\n\n\nscorelist = [1,2,3]\nnp.array(scorelist).sum\n# scorelist = input("문항 배점 리스트(2,3,4,5,6과 같이 수와 컴마로만 입력해주세요. :")\n\n# if scorelist!="":\n#   score = list(map(float, scorelist.split(",")))\n#   N = int(N)\n#   n = int(n)\n#   case = []\n# # 배점당 2문제 이상은 있도록 설정(range(2, n-1))\n#   for s in range(2,n-1):\n#     for w in range(2,n-1):\n#       for z in range(2,n-1):\n#         for y in range(2,n-1):\n#           for x in range(2,n-1):\n#             if (x+y+z+w+s == n)&(score[0]*x+score[1]*y+score[2]*z+score[3]*w+score[4]*s== N)&(z>=np.floor(n/5)) : \n#               # 배점이 중간인 문항 수가 나머지보다 적지는 않게\n#               print(x,y,z,w,s)\n#               case.append([x,y,z,w,s])\n#             else :\n#               continue\n#   if len(case)==0:\n#     print(\'가능한 문항 수가 존재하지 않습니다. 문항 수나 배점 리스트를 다시 설정하세요. \')\n#   else : \n#     print(\'{}가지 모든 경우를 출력하였습니다. \'.format(len(case)))\n\n#sample\n# 3.6, 3.8, 4.0, 4.2, 4.4\n# 4.1, 4.3, 4.5, 4.7, 4.9', 'import numpy as np\nimport pandas as pd\nimport streamlit as st\n\n\nN = 100\nn = 20\n\n\nscorelist = [1,2,3]\nnp.array(scorelist).sum()\n# scorelist = input("문항 배점 리스트(2,3,4,5,6과 같이 수와 컴마로만 입력해주세요. :")\n\n# if scorelist!="":\n#   score = list(map(float, scorelist.split(",")))\n#   N = int(N)\n#   n = int(n)\n#   case = []\n# # 배점당 2문제 이상은 있도록 설정(range(2, n-1))\n#   for s in range(2,n-1):\n#     for w in range(2,n-1):\n#       for z in range(2,n-1):\n#         for y in range(2,n-1):\n#           for x in range(2,n-1):\n#             if (x+y+z+w+s == n)&(score[0]*x+score[1]*y+score[2]*z+score[3]*w+score[4]*s== N)&(z>=np.floor(n/5)) : \n#               # 배점이 중간인 문항 수가 나머지보다 적지는 않게\n#               print(x,y,z,w,s)\n#               case.append([x,y,z,w,s])\n#             else :\n#               continue\n#   if len(case)==0:\n#     print(\'가능한 문항 수가 존재하지 않습니다. 문항 수나 배점 리스트를 다시 설정하세요. \')\n#   else : \n#     print(\'{}가지 모든 경우를 출력하였습니다. \'.format(len(case)))\n\n#sample\n# 3.6, 3.8, 4.0, 4.2, 4.4\n# 4.1, 4.3, 4.5, 4.7, 4.9', 'import numpy as np\nimport pandas as pd\nimport streamlit as st\n\n\nN = 100\nn = 20\n\n\nscorelist = [1,2,3]\nscorelist = np.array(scorelist)\nscorelist.sum()\n# scorelist = input("문항 배점 리스트(2,3,4,5,6과 같이 수와 컴마로만 입력해주세요. :")\n\n# if scorelist!="":\n#   score = list(map(float, scorelist.split(",")))\n#   N = int(N)\n#   n = int(n)\n#   case = []\n# # 배점당 2문제 이상은 있도록 설정(range(2, n-1))\n#   for s in range(2,n-1):\n#     for w in range(2,n-1):\n#       for z in range(2,n-1):\n#         for y in range(2,n-1):\n#           for x in range(2,n-1):\n#             if (x+y+z+w+s == n)&(score[0]*x+score[1]*y+score[2]*z+score[3]*w+sc ...
#        [2],
#        [3]]), 11: array([[100]]), 16: array([ 20.,  50., -50.]), 18: {'var1': None, 'var2': None, 'var3': None, 'var4': None, 'var5': None}, 20: [None, None, None, None, None], 21: [18, 18, 18, 18, 18], 22: ['x1', 'x2', 'x3', 'x4', 'x5'], 23: ['x1', 'x2', 'x3', 'x4', 'x5'], 28: <built-in function globals>, 29: {...}, 32: ['x1', 'x2', 'x3', 'x4', 'x5'], 34: ['y1', 'y2', 'y3', 'y4', 'y5'], 35: 'y1', 36: {'x1': None, 'x2': None, 'x3': None, 'x4': None, 'x5': None}, 39: False, 43: array({'x1': None, 'x2': None, 'x3': None, 'x4': None, 'x5': None},
#       dtype=object), 44: array({'x1': None, 'x2': None, 'x3': None, 'x4': None, 'x5': None},
#       dtype=object), 49: {...}}, '_dh': [WindowsPath('c:/project_sbh/stremlit_RPA/RPA'), WindowsPath('c:/project_sbh/stremlit_RPA/RPA')], 'In': ['', 'import numpy as np\nimport pandas as pd\nimport streamlit as st\n\n\n\n\nN = 100\nn = 20\n\nscorelist = input("문항 배점 리스트(2,3,4,5,6과 같이 수와 컴마로만 입력해주세요. :")\n########\n\n\n\nif scorelist!="":\n  score = list(map(float, scorelist.split(",")))\n  N = int(N)\n  n = int(n)\n  case = []\n# 배점당 2문제 이상은 있도록 설정(range(2, n-1))\n  for s in range(2,n-1):\n    for w in range(2,n-1):\n      for z in range(2,n-1):\n        for y in range(2,n-1):\n          for x in range(2,n-1):\n            if (x+y+z+w+s == n)&(score[0]*x+score[1]*y+score[2]*z+score[3]*w+score[4]*s== N)&(z>=np.floor(n/5)) : \n              # 배점이 중간인 문항 수가 나머지보다 적지는 않게\n              print(x,y,z,w,s)\n              case.append([x,y,z,w,s])\n            else :\n              continue\n\n  if len(case)==0:\n    print(\'가능한 문항 수가 존재하지 않습니다. 문항 수나 배점 리스트를 다시 설정하세요. \')\n  else : \n    print(\'{}가지 모든 경우를 출력하였습니다. \'.format(len(case)))\n\n\n#st.dataframe(pd.DataFrame(case), use_container_width=True)\n\n#sample\n# 3.6, 3.8, 4.0, 4.2, 4.4\n# 4.1, 4.3, 4.5, 4.7, 4.9', 'import numpy as np\nimport pandas as pd\nimport streamlit as st\n\n\nN = 100\nn = 20\n\n\nscorelist = [1,2,3]\nnp.array(scorelist).sum\n# scorelist = input("문항 배점 리스트(2,3,4,5,6과 같이 수와 컴마로만 입력해주세요. :")\n\n# if scorelist!="":\n#   score = list(map(float, scorelist.split(",")))\n#   N = int(N)\n#   n = int(n)\n#   case = []\n# # 배점당 2문제 이상은 있도록 설정(range(2, n-1))\n#   for s in range(2,n-1):\n#     for w in range(2,n-1):\n#       for z in range(2,n-1):\n#         for y in range(2,n-1):\n#           for x in range(2,n-1):\n#             if (x+y+z+w+s == n)&(score[0]*x+score[1]*y+score[2]*z+score[3]*w+score[4]*s== N)&(z>=np.floor(n/5)) : \n#               # 배점이 중간인 문항 수가 나머지보다 적지는 않게\n#               print(x,y,z,w,s)\n#               case.append([x,y,z,w,s])\n#             else :\n#               continue\n#   if len(case)==0:\n#     print(\'가능한 문항 수가 존재하지 않습니다. 문항 수나 배점 리스트를 다시 설정하세요. \')\n#   else : \n#     print(\'{}가지 모든 경우를 출력하였습니다. \'.format(len(case)))\n\n#sample\n# 3.6, 3.8, 4.0, 4.2, 4.4\n# 4.1, 4.3, 4.5, 4.7, 4.9', 'import numpy as np\nimport pandas as pd\nimport streamlit as st\n\n\nN = 100\nn = 20\n\n\nscorelist = [1,2,3]\nnp.array(scorelist).sum()\n# scorelist = input("문항 배점 리스트(2,3,4,5,6과 같이 수와 컴마로만 입력해주세요. :")\n\n# if scorelist!="":\n#   score = list(map(float, scorelist.split(",")))\n#   N = int(N)\n#   n = int(n)\n#   case = []\n# # 배점당 2문제 이상은 있도록 설정(range(2, n-1))\n#   for s in range(2,n-1):\n#     for w in range(2,n-1):\n#       for z in range(2,n-1):\n#         for y in range(2,n-1):\n#           for x in range(2,n-1):\n#             if (x+y+z+w+s == n)&(score[0]*x+score[1]*y+score[2]*z+score[3]*w+score[4]*s== N)&(z>=np.floor(n/5)) : \n#               # 배점이 중간인 문항 수가 나머지보다 적지는 않게\n#               print(x,y,z,w,s)\n#               case.append([x,y,z,w,s])\n#             else :\n#               continue\n#   if len(case)==0:\n#     print(\'가능한 문항 수가 존재하지 않습니다. 문항 수나 배점 리스트를 다시 설정하세요. \')\n#   else : \n#     print(\'{}가지 모든 경우를 출력하였습니다. \'.format(len(case)))\n\n#sample\n# 3.6, 3.8, 4.0, 4.2, 4.4\n# 4.1, 4.3, 4.5, 4.7, 4.9', 'import numpy as np\nimport pandas as pd\nimport streamlit as st\n\n\nN = 100\nn = 20\n\n\nscorelist = [1,2,3]\nscorelist = np.array(scorelist)\nscorelist.sum()\n# scorelist = input("문항 배점 리스트(2,3,4,5,6과 같이 수와 컴마로만 입력해주세요. :")\n\n# if scorelist!="":\n#   score = list(map(float, scorelist.split(",")))\n#   N = int(N)\n#   n = int(n)\n#   case = []\n# # 배점당 2문제 이상은 있도록 설정(range(2, n-1))\n#   for s in range(2,n-1):\n#     for w in range(2,n-1):\n#       for z in range(2,n-1):\n#         for y in range(2,n-1):\n#           for x in range(2,n-1):\n#             if (x+y+z+w+s == n)&(score[0]*x+score[1]*y+score[2]*z+score[3]*w+score[4]*s== N)&(z>=np.floor(n/5)) : \n#               # 배점이 중간인 문항 수가 나머지보다 적지는 않게\n#               print(x,y,z,w,s)\n#    ...
#        [2],
#        [3]]), 11: array([[100]]), 16: array([ 20.,  50., -50.]), 18: {'var1': None, 'var2': None, 'var3': None, 'var4': None, 'var5': None}, 20: [None, None, None, None, None], 21: [18, 18, 18, 18, 18], 22: ['x1', 'x2', 'x3', 'x4', 'x5'], 23: ['x1', 'x2', 'x3', 'x4', 'x5'], 28: <built-in function globals>, 29: {...}, 32: ['x1', 'x2', 'x3', 'x4', 'x5'], 34: ['y1', 'y2', 'y3', 'y4', 'y5'], 35: 'y1', 36: {'x1': None, 'x2': None, 'x3': None, 'x4': None, 'x5': None}, 39: False, 43: array({'x1': None, 'x2': None, 'x3': None, 'x4': None, 'x5': None},
#       dtype=object), 44: array({'x1': None, 'x2': None, 'x3': None, 'x4': None, 'x5': None},
#       dtype=object), 49: {...}}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000002834965DA50>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x0000028349718100>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x0000028349718100>, 'open': <function open at 0x0000028347BEE680>, '_': {...}, '__': array({'x1': None, 'x2': None, 'x3': None, 'x4': None, 'x5': None},
#       dtype=object), '___': array({'x1': None, 'x2': None, 'x3': None, 'x4': None, 'x5': None},
#       dtype=object), '__vsc_ipynb_file__': 'c:\\project_sbh\\stremlit_RPA\\RPA\\scoring_for_exam.ipynb', '_i': "globals()['x1']", '_ii': 'globals()', '_iii': "for i in range(1, 4):\n\tglobals()['x' + str(i)] = None\n\t# globals()['test{}'.format(i)] = i * 10\n \nprint(globals())\n# 결과 : {생략, 'test1': 10, 'test2': 20, 'test3': 30}\n \n# 결과 : 10 20 30", '_i1': 'import numpy as np\nimport pandas as pd\nimport streamlit as st\n\n\n\n\nN = 100\nn = 20\n\nscorelist = input("문항 배점 리스트(2,3,4,5,6과 같이 수와 컴마로만 입력해주세요. :")\n########\n\n\n\nif scorelist!="":\n  score = list(map(float, scorelist.split(",")))\n  N = int(N)\n  n = int(n)\n  case = []\n# 배점당 2문제 이상은 있도록 설정(range(2, n-1))\n  for s in range(2,n-1):\n    for w in range(2,n-1):\n      for z in range(2,n-1):\n        for y in range(2,n-1):\n          for x in range(2,n-1):\n            if (x+y+z+w+s == n)&(score[0]*x+score[1]*y+score[2]*z+score[3]*w+score[4]*s== N)&(z>=np.floor(n/5)) : \n              # 배점이 중간인 문항 수가 나머지보다 적지는 않게\n              print(x,y,z,w,s)\n              case.append([x,y,z,w,s])\n            else :\n              continue\n\n  if len(case)==0:\n    print(\'가능한 문항 수가 존재하지 않습니다. 문항 수나 배점 리스트를 다시 설정하세요. \')\n  else : \n    print(\'{}가지 모든 경우를 출력하였습니다. \'.format(len(case)))\n\n\n#st.dataframe(pd.DataFrame(case), use_container_width=True)\n\n#sample\n# 3.6, 3.8, 4.0, 4.2, 4.4\n# 4.1, 4.3, 4.5, 4.7, 4.9', 'np': <module 'numpy' from 'c:\\Anaconda\\envs\\pytorch_sbh\\lib\\site-packages\\numpy\\__init__.py'>, 'pd': <module 'pandas' from 'c:\\Anaconda\\envs\\pytorch_sbh\\lib\\site-packages\\pandas\\__init__.py'>, 'st': <module 'streamlit' from 'c:\\Anaconda\\envs\\pytorch_sbh\\lib\\site-packages\\streamlit\\__init__.py'>, 'N': 10, 'n': 5, 'scorelist': [3, 4, 5], 'score': [3.0, 4.0, 5.0, 6.0, 7.0], 'case': [[2, 2, 12, 2, 2], [2, 3, 10, 3, 2], [2, 4, 8, 4, 2], [3, 2, 9, 4, 2], [2, 5, 6, 5, 2], [3, 3, 7, 5, 2], [2, 6, 4, 6, 2], [3, 4, 5, 6, 2], [4, 2, 6, 6, 2], [4, 3, 4, 7, 2], [2, 4, 9, 2, 3], [3, 2, 10, 2, 3], [2, 5, 7, 3, 3], [3, 3, 8, 3, 3], [2, 6, 5, 4, 3], [3, 4, 6, 4, 3], [4, 2, 7, 4, 3], [3, 5, 4, 5, 3], [4, 3, 5, 5, 3], [5, 2, 4, 6, 3], [2, 6, 6, 2, 4], [3, 4, 7, 2, 4], [4, 2, 8, 2, 4], [2, 7, 4, 3, 4], [3, 5, 5, 3, 4], [4, 3, 6, 3, 4], [4, 4, 4, 4, 4], [5, 2, 5, 4, 4], [3, 6, 4, 2, 5], [4, 4, 5, 2, 5], [5, 2, 6, 2, 5], [5, 3, 4, 3, 5], [6, 2, 4, 2, 6]], 's': 18, 'w': 18, 'z': 18, 'y': 18, 'x': 18, '_i2': 'import numpy as np\nimport pandas as pd\nimport streamlit as st\n\n\nN = 100\nn = 20\n\n\nscorelist = [1,2,3]\nnp.array(scorelist).sum\n# scorelist = input("문항 배점 리스트(2,3,4,5,6과 같이 수와 컴마로만 입력해주세요. :")\n\n# if scorelist!="":\n#   score = list(map(float, scorelist.split(",")))\n#   N = int(N)\n#   n = int(n)\n#   case = []\n# # 배점당 2문제 이상은 있도록 설정(range(2, n-1))\n#   for s in range(2,n-1):\n#     for w in range(2,n-1):\n#       for z in range(2,n-1):\n#         for y in range(2,n-1):\n#           for x in range(2,n-1):\n#             if (x+y+z+w+s == n)&(score[0]*x+score[1]*y+score[2]*z+score[3]*w+score[4]*s== N)&(z>=np.floor(n/5)) : \n#               # 배점이 중간인 문항 수가 나머지보다 적지는 않게\n#               print(x,y,z,w,s)\n#               case.append([x,y,z,w,s])\n#             else :\n#               continue\n#   if len(case)==0:\n#     print(\'가능한 문항 수가 존재하지 않습니다. 문항 수나 배점 리스트를 다시 설정하세요. \')\n#   else : \n#     print(\'{}가지 모든 경우를 출력하였습니다. \'.format(len(case)))\n\n#sample\n# 3.6, 3.8, 4.0, 4.2, 4.4\n# 4.1, 4.3, 4.5, 4.7, 4.9', '_2': <built-in method sum of numpy.ndarray object at 0x000002834975C450>, '_i3': 'import numpy as np\nimport pandas as pd\nimport streamlit as st\n\n\nN = 100\nn = 20\n\n\nscorelist = [1,2,3]\nnp.array(scorelist).sum()\n# scorelist = input("문항 배점 리스트(2,3,4,5,6과 같이 수와 컴마로만 입력해주세요. :")\n\n# if scorelist!="":\n#   score = list(map(float, scorelist.split(",")))\n#   N = int(N)\n#   n = int(n)\n#   case = []\n# # 배점당 2문제 이상은 있도록 설정(range(2, n-1))\n#   for s in range(2,n-1):\n#     for w in range(2,n-1):\n#       for z in range(2,n-1):\n#         for y  ...
#        [1, 1, 1],
#        [3, 2, 3]]), 'b': array([10, 20, 10]), '_i7': 'scorelist = [1,2,3]\n\nA = np.array([scorelist]).T\nb = np.array([[N]])\nx = np.linalg.solve(A, b)\n\nfor i in range(len(scorelist)):\n    print(f"{chr(ord(\'x\')+i)} = {x[i][0]}")', '_i8': 'scorelist = [1,2,3]\n\nA = np.array([scorelist]).T\nb = np.array([[N]])\nx = np.linalg.solve(A, b)\n\nx', '_i9': 'scorelist = [1,2,3]\n\nA = np.array([scorelist]).T\nb = np.array([[N]])\nx = np.linalg.solve(A, b)\n\nA', '_i10': 'scorelist = [1,2,3]\n\nA = np.array([scorelist]).T\nb = np.array([[N]])\n#x = np.linalg.solve(A, b)\n\nA', '_10': array([[1],
#        [2],
#        [3]]), '_i11': 'scorelist = [1,2,3]\n\nA = np.array([scorelist]).T\nb = np.array([[N]])\n#x = np.linalg.solve(A, b)\n\nb', '_11': array([[100]]), '_i12': 'np.linalg.solve(A, b)', '_i13': 'import numpy as np\n\n# 주어진 리스트\nscorelist = [3, 4, 5]\n\n# 상수\nN = 10\n\n# 계수 행렬과 상수 벡터 만들기\nA = np.array([scorelist]).T\nb = np.array([[N]])\n\n# 선형방정식 해 구하기\nx = np.linalg.solve(A, b)\n\n# 부정방정식 해 구하기\ny1 = np.random.rand(len(scorelist))\ny1 = y1 / np.sum(y1) * N\ny2 = np.random.rand(len(scorelist))\ny2 = y2 / np.sum(y2) * N\n\n# 결과 출력\nprint(f"Linear equation: {\' + \'.join([f\'{scorelist[i]}x_{i}\' for i in range(len(scorelist))])} = {N}")\nfor i in range(len(scorelist)):\n    print(f"x_{i} = {x[i][0]}")\n\nprint(f"\\nNonlinear equation 1: {\' + \'.join([f\'{scorelist[i]}y_{i}\' for i in range(len(scorelist))])} = {N}")\nfor i in range(len(scorelist)):\n    print(f"y1_{i} = {y1[i]}")\n\nprint(f"\\nNonlinear equation 2: {\' + \'.join([f\'{scorelist[i]}y_{i}\' for i in range(len(scorelist))])} = {N}")\nfor i in range(len(scorelist)):\n    print(f"y2_{i} = {y2[i]}")', '_i14': 'A = np.array([[3,4,5], [1,1,1]])\nb = np.array([N, n])\nnp.linalg.solve(A, b)', '_i15': 'A = np.array([[3,4,5], [1,1,1], [3,2,3]])\nb = np.array([N, n])\nnp.linalg.solve(A, b)', '_i16': 'A = np.array([[3,4,5], [1,1,1], [3,2,3]])\nb = np.array([N, n,10])\nnp.linalg.solve(A, b)', '_16': array([ 20.,  50., -50.]), '_i17': 'n = 5\nvariables = {}\nfor i in range(n):\n    variables[f"var{i+1}"] = None', 'variables': {'x1': None, 'x2': None, 'x3': None, 'x4': None, 'x5': None}, 'i': 3, '_i18': 'n = 5\nvariables = {}\nfor i in range(n):\n    variables[f"var{i+1}"] = None\n\nvariables', '_18': {'var1': None, 'var2': None, 'var3': None, 'var4': None, 'var5': None}, '_i19': 'variables = [None] * n', '_i20': 'variables = [None] * n\nvariables', '_20': [None, None, None, None, None], '_i21': 'variables = [x] * n\nvariables', '_21': [18, 18, 18, 18, 18], '_i22': '# 변수 세팅하기\nx_list = []\nfor i in range(1, n+1):\n    x_list.append("x"+str(i))\nx_list', 'x_list': ['y1', 'y2', 'y3', 'y4', 'y5'], '_22': ['x1', 'x2', 'x3', 'x4', 'x5'], '_i23': '# 변수 세팅하기\nx_list = []\nfor i in range(1, n+1):\n    x_list.append("x"+str(i))\nx_list', '_23': ['x1', 'x2', 'x3', 'x4', 'x5'], '_i24': 'for x1 in range(2, 5):\n    print(2*x1)', 'x1': 10, '_i25': 'n = 5\nfor i in range(1, n+1):\n    globals()["x" + str(i)] = None', 'x2': 10, 'x3': 10, 'x4': None, 'x5': None, '_i26': 'x1', '_i27': 'x2', '_i28': 'globals', '_28': <built-in function globals>, '_i29': 'globals()', '_29': {...}, '_i30': 'globals x1', '_i31': 'n = 5\nx_list = []\nfor i in range(1, n+1):\n    globals()["x" + str(i)] = None\n    x_list.append("x" + str(i))', '_i32': 'x_list', '_32': ['x1', 'x2', 'x3', 'x4', 'x5'], '_i33': 'n = 5\nx_list = []\nfor i in range(1, n+1):\n    globals()["x" + str(i)] = None\n    x_list.append("y" + str(i))', '_i34': 'x_list', '_34': ['y1', 'y2', 'y3', 'y4', 'y5'], '_i35': 'x_list[0]', '_35': 'y1', '_i36': 'n = 5\nvariables = {}\nfor i in range(n):\n    variables[f"x{i+1}"] = None\n\nvariables', '_36': {'x1': None, 'x2': None, 'x3': None, 'x4': None, 'x5': None}, '_i37': 'n = 5\nvariables = {}\nfor i in range(n):\n    variables[f"x{i+1}"] = None\n\nvariables[0]', '_i38': 'n = 5\nvariables = {}\nfor i in range(n):\n    variables[f"x{i+1}"] = None\n\nvariables[\'x1\']', '_i39': 'n = 5\nvariables = {}\nfor i in range(n):\n    variables[f"x{i+1}"] = None\n\nvariables[\'x1\']==1', '_39': False, '_i40': 'variables.sum()', '_i41': 'variables.tolist()', '_i42': 'variables.tolist', '_i43': 'np.array(variables)', '_43': array({'x1': None, 'x2': None, 'x3': None, 'x4': None, 'x5': None},
#       dtype=object), '_i44': 'np.array(variables)', '_44': array({'x1': None, 'x2': None, 'x3': None, 'x4': None, 'x5': None},
#       dtype=object), '_i45': "globals()['test'] = 100\t# {'test': 100} item 추가\nprint(globals())\n# 결과 : {생략, 'test': 100}", 'test': 100, '_i46': "for i in range(1, 4):\n\tglobals()['test' + str(i)] = i * 10\n\t# globals()['test{}'.format(i)] = i * 10\n \nprint(globals())\n# 결과 : {생략, 'test1': 10, 'test2': 20, 'test3': 30}\n \nprint(test1, test2, test3)\n# 결과 : 10 20 30", 'test1': 10, 'test2': 20, 'test3': 30, '_i47': "for i in range(1, 4):\n\tglobals()['x' + str(i)] = i * 10\n\t# globals()['test{}'.format(i)] = i * 10\n \nprint(globals())\n# 결과 : {생략, 'test1': 10, 'test2': 20, 'test3': 30}\n \n# 결과 : 10 20 30", '_i48': "for i in range(1, 4):\n\tglobals()['x' + str(i)] = None\n\t# globals()['test{}'.format(i)] = i * 10\n \nprint(globals())\n# 결과 : {생략, 'test1': 10, 'test2': 20, 'test3': 30}\n \n# 결과 : 10 20 30", '_i49': 'globals()', '_49': {...}, '_i50': "globals()['x1']", '_i51': "for i in range(1, 4):\n\tglobals()['x' + str(i)] = 10\n\t# globals()['test{}'.format(i)] = i * 10\n \nprint(globals())\n# 결과 : {생략, 'test1': 10, 'test2': 20, 'test3': 30}\n \n# 결과 : 10 20 30"}

# %%
globals()[x_list[0]] = 5
globals()[x_list[0]]
# Out:
# 5

# %%
for i in range(1, 5):
	globals()['x' + str(i)] = 10

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 scorelist
#
# NameError: name 'scorelist' is not defined

# %%
import numpy as np
# Out:
# array([-60.,  70.])

# %%
# Out:
# array([ 37., -36.,  22.])

# %%
import numpy as np
#3개##########################################
scorelist = [4,5,6]
N = 100
n = 23

# 변수 생성하기
x_list = [] 
for i in range(1, len(scorelist)+1):
	globals()['x' + str(i)] = None
	x_list.append('x' + str(i))

print(scorelist,"점 짜리 문항의 개수는 각각 다음과 같습니다.")
A = np.array([scorelist, np.ones(len(scorelist)).tolist()])

sol_list = []
#b = [N, n]
for globals()[x_list[-1]] in range(1,n):
    b = [N-globals()[x_list[-1]]*scorelist[-1], 
         n-globals()[x_list[-1]]]
    sol = np.linalg.solve(A.T[:-1].T, b)

    if np.all(sol > 0):
        sol = np.append(sol, globals()[x_list[-1]])
        sol_list.append(sol)
    else:
        continue

import pandas as pd
total_sol = pd.DataFrame(sol_list, columns=scorelist).sort_index(axis =1)
display(total_sol)
# Out:
# [4, 5, 6] 점 짜리 문항의 개수는 각각 다음과 같습니다.
#       4    5    6
# 0  16.0  6.0  1.0
# 1  17.0  4.0  2.0
# 2  18.0  2.0  3.0

# %%
#4개##########################################
scorelist = [4,5,7,6]
N = 100
n = 20

# 변수 생성하기
x_list = [] 
for i in range(1, len(scorelist)+1):
	globals()['x' + str(i)] = None
	x_list.append('x' + str(i))

print(scorelist,"점 짜리 문항의 개수는 각각 다음과 같습니다.")

sol_list = []
A = np.array([scorelist, np.ones(len(scorelist)).tolist()])
for globals()[x_list[-1]] in range(1,n):
    ############################ 3개일 때 
    b = [N-globals()[x_list[-1]]*scorelist[-1], 
         n-globals()[x_list[-1]]]
    try: 
        sol = np.linalg.solve(A.T[:-1].T, b)
        if np.all(sol > 0):
            sol = np.append(sol, globals()[x_list[-1]])
            sol_list.append(sol)
        else:
            continue
    except: ##################### 4개일 때 
        #####################################################
        #####################################################
        for globals()[x_list[-2]] in range(1,n):
            b = [N-globals()[x_list[-1]]*scorelist[-1] 
                -globals()[x_list[-2]]*scorelist[-2], 
                n-globals()[x_list[-1]]
                -globals()[x_list[-2]]]
            sol = np.linalg.solve(A.T[:-2].T, b)
            if np.all(sol > 0):
                sol = np.append(sol, globals()[x_list[-2]])
                sol = np.append(sol, globals()[x_list[-1]])
                sol_list.append(sol)
            else:
                continue
        #####################################################
        #####################################################

import pandas as pd
total_sol = pd.DataFrame(sol_list, columns=scorelist).sort_index(axis =1)
display(total_sol)
# Out:
# [4, 5, 7, 6] 점 짜리 문항의 개수는 각각 다음과 같습니다.
#        4     5    6    7
# 0    3.0  15.0  1.0  1.0
# 1    5.0  12.0  1.0  2.0
# 2    7.0   9.0  1.0  3.0
# 3    9.0   6.0  1.0  4.0
# 4   11.0   3.0  1.0  5.0
# 5    4.0  13.0  2.0  1.0
# 6    6.0  10.0  2.0  2.0
# 7    8.0   7.0  2.0  3.0
# 8   10.0   4.0  2.0  4.0
# 9   12.0   1.0  2.0  5.0
# 10   5.0  11.0  3.0  1.0
# 11   7.0   8.0  3.0  2.0
# 12   9.0   5.0  3.0  3.0
# 13  11.0   2.0  3.0  4.0
# 14   6.0   9.0  4.0  1.0
# 15   8.0   6.0  4.0  2.0
# 16  10.0   3.0  4.0  3.0
# 17   7.0   7.0  5.0  1.0
# 18   9.0   4.0  5.0  2.0
# 19  11.0   1.0  5.0  3.0
# 20   8.0   5.0  6.0  1.0
# 21  10.0   2.0  6.0  2.0
# 22   9.0   3.0  7.0  1.0
# 23  10.0   1.0  8.0  1.0

# %%
def indef_eq_3(scorelist, N, n):
    sol_list = []
    for globals()[x_list[-1]] in range(1,n):
        A = np.array([scorelist, np.ones(len(scorelist)).tolist()])
        b = [N-globals()[x_list[-1]]*scorelist[-1], 
             n-globals()[x_list[-1]]]
        sol = np.linalg.solve(A.T[:-1].T, b)
        if np.all(sol > 0):
            #print(sol,globals()[x_list[0]])
            sol = np.append(sol, globals()[x_list[-1]])
            sol_list.append(sol)
        else:
            continue
    return pd.DataFrame(sol_list, columns=scorelist).sort_index(axis =1)

def indef_eq_4(scorelist, N, n):
    sol_list = []
    for globals()[x_list[-1]] in range(1,n):
        for globals()[x_list[-2]] in range(1,n):
            A = np.array([scorelist, np.ones(len(scorelist)).tolist()])
            b = [N-globals()[x_list[-1]]*scorelist[-1] 
                -globals()[x_list[-2]]*scorelist[-2], 
                n-globals()[x_list[-1]]
                -globals()[x_list[-2]]]
            sol = np.linalg.solve(A.T[:-2].T, b)
            if np.all(sol > 0):
                sol = np.append(sol, globals()[x_list[-2]])
                sol = np.append(sol, globals()[x_list[-1]])
                sol_list.append(sol)
            else:
                continue
    return pd.DataFrame(sol_list, columns=scorelist).sort_index(axis =1)

def indef_eq_5(scorelist, N, n):
    sol_list = []
    for globals()[x_list[-1]] in range(1,n):
        for globals()[x_list[-2]] in range(1,n):
            for globals()[x_list[-3]] in range(1,n):
                A = np.array([scorelist, np.ones(len(scorelist)).tolist()])
                b = [N-globals()[x_list[-1]]*scorelist[-1] 
                      -globals()[x_list[-2]]*scorelist[-2]
                      -globals()[x_list[-3]]*scorelist[-3], 
                    n-globals()[x_list[-1]]
                     -globals()[x_list[-2]]
                     -globals()[x_list[-3]]]
                sol = np.linalg.solve(A.T[:-3].T, b)
                if np.all(sol > 0):
                    sol = np.append(sol, globals()[x_list[-3]])
                    sol = np.append(sol, globals()[x_list[-2]])
                    sol = np.append(sol, globals()[x_list[-1]])
                    sol_list.append(sol)
                else:
                    continue
    return pd.DataFrame(sol_list, columns=scorelist).sort_index(axis =1)

# %%
def nb_of_item(scorelist):
    x_list = [] 
    for i in range(1, len(scorelist)+1):
        globals()['x' + str(i)] = None
        x_list.append('x' + str(i))
            
    if len(scorelist)==3:
        df = indef_eq_3(scorelist, N, n)
    elif len(scorelist)==4:
        df = indef_eq_4(scorelist, N, n)
    elif len(scorelist)==5:
        df = indef_eq_5(scorelist, N, n)
    else:
        print('배점 종류를 5개 이하로 입력해주세요. ')
    return df


scorelist = [4,5,5.5,6]
N = 100
n = 20

nb_of_item(scorelist)
# Out:
#     4.0   5.0   5.5  6.0
# 0   1.5  16.5   1.0  1.0
# 1   2.0  15.0   2.0  1.0
# 2   2.5  13.5   3.0  1.0
# 3   3.0  12.0   4.0  1.0
# 4   3.5  10.5   5.0  1.0
# 5   4.0   9.0   6.0  1.0
# 6   4.5   7.5   7.0  1.0
# 7   5.0   6.0   8.0  1.0
# 8   5.5   4.5   9.0  1.0
# 9   6.0   3.0  10.0  1.0
# 10  6.5   1.5  11.0  1.0
# 11  2.5  14.5   1.0  2.0
# 12  3.0  13.0   2.0  2.0
# 13  3.5  11.5   3.0  2.0
# 14  4.0  10.0   4.0  2.0
# 15  4.5   8.5   5.0  2.0
# 16  5.0   7.0   6.0  2.0
# 17  5.5   5.5   7.0  2.0
# 18  6.0   4.0   8.0  2.0
# 19  6.5   2.5   9.0  2.0
# 20  7.0   1.0  10.0  2.0
# 21  3.5  12.5   1.0  3.0
# 22  4.0  11.0   2.0  3.0
# 23  4.5   9.5   3.0  3.0
# 24  5.0   8.0   4.0  3.0
# 25  5.5   6.5   5.0  3.0
# 26  6.0   5.0   6.0  3.0
# 27  6.5   3.5   7.0  3.0
# 28  7.0   2.0   8.0  3.0
# 29  7.5   0.5   9.0  3.0
# 30  4.5  10.5   1.0  4.0
# 31  5.0   9.0   2.0  4.0
# 32  5.5   7.5   3.0  4.0
# 33  6.0   6.0   4.0  4.0
# 34  6.5   4.5   5.0  4.0
# 35  7.0   3.0   6.0  4.0
# 36  7.5   1.5   7.0  4.0
# 37  5.5   8.5   1.0  5.0
# 38  6.0   7.0   2.0  5.0
# 39  6.5   5.5   3.0  5.0
# 40  7.0   4.0   4.0  5.0
# 41  7.5   2.5   5.0  5.0
# 42  8.0   1.0   6.0  5.0
# 43  6.5   6.5   1.0  6.0
# 44  7.0   5.0   2.0  6.0
# 45  7.5   3.5   3.0  6.0
# 46  8.0   2.0   4.0  6.0
# 47  8.5   0.5   5.0  6.0
# 48  7.5   4.5   1.0  7.0
# 49  8.0   3.0   2.0  7.0
# 50  8.5   1.5   3.0  7.0
# 51  8.5   2.5   1.0  8.0
# 52  9.0   1.0   2.0  8.0
# 53  9.5   0.5   1.0  9.0

# %%
indef_eq_5([3,4,5,6,7], N, n)
# Out:
#        3    4     5    6    7
# 0    1.0  1.0  16.0  1.0  1.0
# 1    1.0  2.0  14.0  2.0  1.0
# 2    1.0  3.0  12.0  3.0  1.0
# 3    2.0  1.0  13.0  3.0  1.0
# 4    1.0  4.0  10.0  4.0  1.0
# ..   ...  ...   ...  ...  ...
# 145  6.0  4.0   1.0  2.0  7.0
# 146  7.0  2.0   2.0  2.0  7.0
# 147  8.0  1.0   1.0  3.0  7.0
# 148  7.0  3.0   1.0  1.0  8.0
# 149  8.0  1.0   2.0  1.0  8.0
#
# [150 rows x 5 columns]
